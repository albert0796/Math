# %%
from sympy import symbols
from sympy.plotting import plot
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from sympy import *
init_printing()

# %%
x = symbols('x')
p1 = plot(x*x, show=False)
p2 = plot(x, show=False)
p1.append(p2[0])
p1.show()

# %%
x = symbols('x')
p1 = plot(x*x, show=False)
p2 = plot(x,-x, show=False)
p1.extend(p2)
p1.show()

# %%
from sympy import symbols, cos, sin
from sympy.plotting import plot_parametric
plot(x**2, (x, -5, 5))

# %%
plot_parametric(cos(x), sin(x), (x, -5, 5))

# %%
from sympy.plotting import plot3d
x,y=symbols('x y')
plot3d(x*y, (x, -5, 5), (y, -5, 5))

# %%
plot3d(2*x**2+3*y**2, (x, -50, 50), (y, -50, 50))

# %%
plot3d(-2*x**2-3*y**2, (x, -50, 50), (y, -50, 50))

# %%
plot3d(2*x**2-3*y**2)

# %%
x, y=symbols('x y')
a, b=symbols('a b',integer=True)
z, f, g =symbols('z f g',cls=Function)

# %%
z=a*x**2+b*y**2
z
# Out:
#    2      2
# a⋅x  + b⋅y

# %%
f=z.subs(a,2).subs(b,3)
plot3d(f)

# %%
plot3d(2*x**2+0*y**1)

# %%
import sympy as sp
sp.init_printing()
lam = symbols('lamda')
p = A.charpoly(lam)     # charploy: characteristic polynomial,
factor(p)
A=Matrix([[2,-3],[-3,5]])
A
# Out:
#  2
# λ  - 7⋅λ + 1
# ⎡2   -3⎤
# ⎢      ⎥
# ⎣-3  5 ⎦

# %%
x1, x2 = symbols('x1 x2')
y1, y2 = symbols('y1 y2')
# a, b, c, d, e, f = symbols('a b c d e f', integer = True)
f, g = symbols('f g', cls = Function)

# %%
x=Matrix([[x1],[x2]])

# %%
f = x.transpose() * A * x
f
expand(f)
# Out:
# [x₁⋅(2⋅x₁ - 3⋅x₂) + x₂⋅(-3⋅x₁ + 5⋅x₂)]
# ⎡    2                 2⎤
# ⎣2⋅x₁  - 6⋅x₁⋅x₂ + 5⋅x₂ ⎦

# %%
lam = symbols('lamda')
p = A.charpoly(lam)     # charploy: characteristic polynomial
p
factor(p)#因式分解
# Out:
# PurePoly(lamda**2 - 7*lamda + 1, lamda, domain='ZZ')
#  2
# λ  - 7⋅λ + 1

# %%
P, D = A.diagonalize()
P
D

(P ** -1) * D * P
# Out:
# ⎡1   √5  1   √5⎤
# ⎢─ + ──  ─ - ──⎥
# ⎢2   2   2   2 ⎥
# ⎢              ⎥
# ⎣  1       1   ⎦
# ⎡7   3⋅√5          ⎤
# ⎢─ - ────     0    ⎥
# ⎢2    2            ⎥
# ⎢                  ⎥
# ⎢          3⋅√5   7⎥
# ⎢   0      ──── + ─⎥
# ⎣           2     2⎦
# ⎡    ⎛1   √5⎞ ⎛7   3⋅√5⎞      ⎛1   √5⎞ ⎛3⋅√5   7⎞       ⎛1   √5⎞ ⎛7   3⋅√5⎞
# ⎢ √5⋅⎜─ + ──⎟⋅⎜─ - ────⎟   √5⋅⎜─ - ──⎟⋅⎜──── + ─⎟    √5⋅⎜─ - ──⎟⋅⎜─ - ────⎟
# ⎢    ⎝2   2 ⎠ ⎝2    2  ⎠      ⎝2   2 ⎠ ⎝ 2     2⎠       ⎝2   2 ⎠ ⎝2    2  ⎠
# ⎢ ────────────────────── - ──────────────────────    ────────────────────── -
# ⎢           5                        5                         5
# ⎢
# ⎢     ⎛1   √5⎞ ⎛7   3⋅√5⎞      ⎛1   √5⎞ ⎛3⋅√5   7⎞       ⎛1   √5⎞ ⎛7   3⋅√5⎞
# ⎢  √5⋅⎜─ + ──⎟⋅⎜─ - ────⎟   √5⋅⎜─ + ──⎟⋅⎜──── + ─⎟    √5⋅⎜─ - ──⎟⋅⎜─ - ────⎟
# ⎢     ⎝2   2 ⎠ ⎝2    2  ⎠      ⎝2   2 ⎠ ⎝ 2     2⎠       ⎝2   2 ⎠ ⎝2    2  ⎠
# ⎢- ────────────────────── + ──────────────────────  - ────────────────────── +
# ...
